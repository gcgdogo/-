# %%
from Data_Source import *

# %%
ds = Data_Source('中国强化知识产权保护为创新发展“护航”.repr.txt',4)

# %%
ds.List_Choices
# Out:
# [['世界知识产权组织', 41, -3],
#  ['近日发布', 49, 1],
#  ['2019年版', 53, 2],
#  ['《世界知识产权', 59, 3],
#  ['报告》，', 66, 0],
#  ['揭示', 70, -1],
#  ['全球创新新趋势，', 72, 6],
#  ['再度肯定', 80, 7],
#  ['中国在', 84, 4],
#  ['技术创新', 87, 9],
#  ['和知识产权保护', 91, 5],
#  ['方面', 98, -2],
#  ['的进步。', 100, 11],
#  ['之所以', 106, 12],
#  ['说“再度”，是因为', 109, 8],
#  ['今年10月', 118, 10],
#  ['该组织', 123, 13],
#  ['在其发布的', 126, 15],
#  ['《世界知识产权', 131, 17],
#  ['指标》', 138, 14],
#  ['年度报告中', 141, 18],
#  ['指出，', 146, 19],
#  ['2018年', 149, 22],
#  ['全球专利、商标', 154, 16],
#  ['及工业品外观', 161, 24],
#  ['设计申请量', 167, 21],
#  ['再创新高，', 172, 23],
#  ['其中', 177, 27],
#  ['中国专利和商标', 179, 28],
#  ['申请数量最多，', 186, 25],
#  ['推动了', 193, 26],
#  ['知识产权', 196, 31],
#  ['需求的整体增长。', 200, 20],
#  ['再往前3个月，', 208, 29],
#  ['该组织参与发布', 215, 32],
#  ['的2019年', 222, 35],
#  ['全球创新指数', 228, 34],
#  ['显示，', 234, 33],
#  ['中国', 237, 30],
#  ['连续第四年保持', 239, 36],
#  ['上升势头，', 246, 39],
#  ['排在第14位，', 251, 37],
#  ['较去年上升', 258, 41],
#  ['3个位次……', 263, 40],
# ...

# %%
len(ds.List_Choices)
# Out:
# 265

# %%
ds.PreLoad_Text()
# Out:
# ['世界知识产权组织', '报告》，', '揭示', '方面']

# %%
ds.Visable_Doc()
# Out:
# '中国强化知识产权保护为创新发展“护航”\n====================\n'

# %%
ds.Whole_Doc()
# Out:
# '中国强化知识产权保护为创新发展“护航”\n====================\n[color=3333cc]世界知识产权组织近日发布2019年版《世界知识产权报告》，揭示全球创新新趋势，再度肯定中国在技术创新和知识产权保护方面的进步。[/color]\n\n[color=3333cc]之所以说“再度”，是因为今年10月该组织在其发布的《世界知识产权指标》年度报告中指出，2018年全球专利、商标及工业品外观设计申请量再创新高，其中中国专利和商标申请数量最多，推动了知识产权需求的整体增长。再往前3个月，该组织参与发布的2019年全球创新指数显示，中国连续第四年保持上升势头，排在第14位，较去年上升3个位次……[/color]\n\n[color=3333cc]知识产权保护是创新驱动发展的“刚需”，是国际贸易的“标配”。世界知识产权组织的报告反映一个基本事实：中国高度重视知识产权保护，中国知识产权保护和技术创新正在形成良性互动，助力中国实现从技术引进向自主创新转型，为全球创新成果共享牵线搭桥，为人类科技进步输送动力。[/color]\n\n[color=3333cc]中国不断加强知识产权保护，推动技术创新为中国经济注入新活力。[/color]\n\n[color=3333cc]当前，知识产权已成为中国加快转变经济发展方式、保障和推动创新型国家建设的重要驱动力。数据显示，2018年中国国家知识产权局受理的专利申请数量达到约154万件，占全球总量的46.4%，数量居全球第一；同年，国外在华发明专利申请量达14.8万件，同比增长9.1%，实现“十三五”以来最快增速……[/color]\n\n[color=3333cc]如今，中国高科技企业已实现从模仿者向全球创新领先者的华丽转身。在教育、出行、数字支付、医疗健康等领域，自主创新日趋活跃，新技术应用不断涌现。中国取得如此成就，背后既有政策支持、开放合作、市场巨大、人才众多等因素支持，同时也离不开中国知识产权保护制度营造的良好创新环境和营商环境。[/color]\n\n[color=3333cc]过去几十年来，中国坚定不移实施严格的知识产权保护制度，在加强知识产权制度建设、完善相关法律基础、打造专门法院等基础设施方面取得重大成效。与此同时，知识产权保护效果、运用效益和国际影响力不断得到提升，实现了由知识产权弱国向知识产权
# ...

# %%
ds.Check_Text('世界知识产权组织123')
# Out:
# False

# %%
ds.Next_Text()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-31040c859d20> in <module>
# ----> 1 ds.Next_Text()
#
# f:\Site\GitHub\-\py_Kivy_Tester\Data_Source.py in Next_Text(self)
#      53     def Next_Text(self):
#      54         self.Finger = self.Finger + 1
# ---> 55         for I in self.List_Choices[self.Finger,]:
#      56             if I[2] == self.Finger :
#      57                 return I[0]
#
# TypeError: list indices must be integers or slices, not tuple
